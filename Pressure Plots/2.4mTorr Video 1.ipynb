# %%
f = open("/Users/Bianca/Desktop/Pressure Data/1.6kW_2.4mTorr forward video1.txt", "r")
print(f.read())
f.close()
# Out:
# 1065.25	1.49
# 1095.4	1.49
# 1125.55	1.49
# 1155.7	1.5
# 1185.85	1.5
# 1216	1.51
# 1246.15	1.52
# 1276.3	1.63
# 1306.45	1.63
# 1336.6	1.62

# %%
f = open("/Users/Bianca/Desktop/Pressure Data/1.6kW_2.4mTorr reverse video1.txt", "r")
print(f.read())
f.close()
# Out:
# 1065.25	1.48
# 1095.4	1.49
# 1125.55	1.5
# 1155.7	1.51
# 1185.85	1.51
# 1216	1.62
# 1246.15	1.62
# 1276.3	1.62
# 1306.45	1.62
# 1336.6	1.62

# %%
# %matplotlib notebook
import csv
import numpy as np
import os, sys

# %%
#reader = csv.list_dialects(f)
f = open("/Users/Bianca/Desktop/Pressure Data/1.6kW_2.4mTorr forward video1.txt","r")
#print(f.read())
reader = csv.reader(f, delimiter = '\n')
result = np.array(list(reader))
#print(result)
f.close()

# %%
#reader = csv.list_dialects(f)
f = open("/Users/Bianca/Desktop/Pressure Data/1.6kW_2.4mTorr reverse video1.txt","r")
#print(f.read())
reader1 = csv.reader(f, delimiter = '\n')
result1 = np.array(list(reader1))
#print(result1)
f.close()

# %%
pressure_y1 = []
b_field_x1 = []

for i in range (0, len(result)):
    x = result[i]
    dat = x[0].split('\t')
    b = float(dat[0])
    p = float(dat[1])
    b_field_x1.append(b)
    pressure_y1.append(p)
f.close()
#print(pressure_y)

# %%
pressure_y2 = []
b_field_x2 = []

for i in range (0, len(result1)):
    x = result1[i]
    dat = x[0].split('\t')
    b = float(dat[0])
    p = float(dat[1])
    b_field_x2.append(b)
    pressure_y2.append(p)
f.close()
#print(pressure_y)

# %%
import matplotlib
import matplotlib.pyplot as plt
from IPython.core.display import HTML
from IPython.core.pylabtools import figsize
from matplotlib.legend_handler import HandlerLine2D

figsize(7,4)
x1 = b_field_x1
y1 = pressure_y1

x2 = b_field_x2
y2 = pressure_y2

plt.xlabel('Magnetic Field (Gauss)')
plt.ylabel('Pressure (mTorr)')
plt.title('1.6kW_25sccm_2.4mTorr Video1')
#plt.plot(x1,y1, 'b')
#plt.plot(x2,y2, "r")
line1, = plt.plot(x1,y1, 'b', marker= 'o', label= 'Forward')
line2, = plt.plot(x2,y2, 'r', marker= 'o', label= 'Reverse') 
plt.legend(handler_map={line1:HandlerLine2D(numpoints=1)})

plt.show()


#print(x1)
f.close()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#y1, y2
# Out:
# ([1.49, 1.49, 1.49, 1.5, 1.5, 1.51, 1.52, 1.63, 1.63, 1.62],
#  [1.48, 1.49, 1.5, 1.51, 1.51, 1.62, 1.62, 1.62, 1.62, 1.62])
